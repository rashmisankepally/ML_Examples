# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
df = pd.read_excel(r'C:\bharath\DS\train.xlsx')

# %%
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %%
print(df.dtypes)
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
# Alley             object
# LotShape          object
# LandContour       object
# Utilities         object
# LotConfig         object
# LandSlope         object
# Neighborhood      object
# Condition1        object
# Condition2        object
# BldgType          object
# HouseStyle        object
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# RoofStyle         object
# RoofMatl          object
# Exterior1st       object
# Exterior2nd       object
# MasVnrType        object
# MasVnrArea       float64
# ExterQual         object
# ExterCond         object
# Foundation        object
# BsmtQual          object
# BsmtCond          object
# BsmtExposure      object
# BsmtFinType1      object
# BsmtFinSF1         int64
# BsmtFinType2      object
# BsmtFinSF2         int64
# ...

# %%
x = df.SalePrice.mean()         
x
# Out:
# 180921.19589041095

# %%
sns.set(rc={'figure.figsize':(12,12)})
sns.distplot(df.SalePrice);
plt.axvline(x,0,1,color = 'Red')

# %%
df.corr()
# Out:
#                      Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# Id             1.000000    0.011156    -0.010601 -0.033226    -0.028365
# MSSubClass     0.011156    1.000000    -0.386347 -0.139781     0.032628
# LotFrontage   -0.010601   -0.386347     1.000000  0.426095     0.251646
# LotArea       -0.033226   -0.139781     0.426095  1.000000     0.105806
# OverallQual   -0.028365    0.032628     0.251646  0.105806     1.000000
# OverallCond    0.012609   -0.059316    -0.059213 -0.005636    -0.091932
# YearBuilt     -0.012713    0.027850     0.123349  0.014228     0.572323
# YearRemodAdd  -0.021998    0.040581     0.088866  0.013788     0.550684
# MasVnrArea    -0.050298    0.022936     0.193458  0.104160     0.411876
# BsmtFinSF1    -0.005024   -0.069836     0.233633  0.214103     0.239666
# BsmtFinSF2    -0.005968   -0.065649     0.049900  0.111170    -0.059119
# BsmtUnfSF     -0.007940   -0.140759     0.132644 -0.002618     0.308159
# ...

# %%
corrMatrix = df.corr()['SalePrice']
type(corrMatrix)
# Out:
# pandas.core.series.Series

# %%
#generating correlation values of the numerical variables with the Saleprice in the ascending order
corrMatrix = corrMatrix.sort_values(ascending = False)
df2 =  pd.DataFrame()
list1 = list(corrMatrix.index)
list1
# Out:
# ['SalePrice',
#  'OverallQual',
#  'GrLivArea',
#  'GarageCars',
#  'GarageArea',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  'FullBath',
#  'TotRmsAbvGrd',
#  'YearBuilt',
#  'YearRemodAdd',
#  'GarageYrBlt',
#  'MasVnrArea',
#  'Fireplaces',
#  'BsmtFinSF1',
#  'LotFrontage',
#  'WoodDeckSF',
#  '2ndFlrSF',
#  'OpenPorchSF',
#  'HalfBath',
#  'LotArea',
#  'BsmtFullBath',
#  'BsmtUnfSF',
#  'BedroomAbvGr',
#  'ScreenPorch',
#  'PoolArea',
#  'MoSold',
#  '3SsnPorch',
#  'BsmtFinSF2',
#  'BsmtHalfBath',
#  'MiscVal',
#  'Id',
#  'LowQualFinSF',
#  'YrSold',
#  'OverallCond',
#  'MSSubClass',
#  'EnclosedPorch',
#  'KitchenAbvGr']

# %%
df1 = df.loc[:, df.columns.isin(list1[0:20])]

# %%
#removing outliers with respect to the Target variable saleprice
dffilter = df1[df1['SalePrice']<400000]

# %%
sns.distplot(dffilter['SalePrice'])

# %%
dffilter.isna().sum()
# Out:
# LotFrontage     257
# OverallQual       0
# YearBuilt         0
# YearRemodAdd      0
# MasVnrArea        7
# BsmtFinSF1        0
# TotalBsmtSF       0
# 1stFlrSF          0
# 2ndFlrSF          0
# GrLivArea         0
# FullBath          0
# HalfBath          0
# TotRmsAbvGrd      0
# Fireplaces        0
# GarageYrBlt      81
# GarageCars        0
# GarageArea        0
# WoodDeckSF        0
# OpenPorchSF       0
# SalePrice         0
# dtype: int64

# %%
dffilter['LotFrontage'].fillna(round(dffilter['LotFrontage'].mean(),2),inplace = True)
# Out:
# C:\Users\bhara\AppData\Roaming\Python\Python37\site-packages\pandas\core\generic.py:6287: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)

# %%
dffilter['MasVnrArea'].fillna(round(dffilter['MasVnrArea'].mean(),2),inplace = True)

# %%
dffilter['GarageYrBlt'].fillna(round(dffilter['GarageYrBlt'].mean(),2),inplace = True)

# %%
Target = dffilter[['SalePrice']]

# %%
Train = dffilter.drop(['SalePrice'],axis =1)

# %%
Target
# Out:
#       SalePrice
# 0        208500
# 1        181500
# 2        223500
# 3        140000
# 4        250000
# 5        143000
# 6        307000
# 7        200000
# 8        129900
# 9        118000
# 10       129500
# 11       345000
# 12       144000
# 13       279500
# 14       157000
# 15       132000
# 16       149000
# 17        90000
# 18       159000
# 19       139000
# 20       325300
# 21       139400
# 22       230000
# 23       129900
# 24       154000
# 25       256300
# 26       134800
# 27       306000
# 28       207500
# 29        68500
# 30        40000
# 31       149350
# 32       179900
# 33       165500
# 34       277500
# 35       309000
# 36       145000
# 37       153000
# 38       109000
# 39        82000
# 40       160000
# 41       170000
# 42       144000
# 43       130250
# 44       141000
# 45       319900
# 46       239686
# 47       249700
# 48       113000
# 49       127000
# 50       177000
# 51       114500
# 52       110000
# 53       385000
# ...

# %%
len(Train.columns)
# Out:
# 19

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression().fit(Train,Target)

# %%
df2 = pd.read_csv(r'C:\bharath\DS\test.csv')
df2 = df2.select_dtypes(include = ['int64','float64'])

# %%
len(df2.columns)
# Out:
# 37

# %%
df2.isna().sum()
# Out:
# Id                 0
# MSSubClass         0
# LotFrontage      227
# LotArea            0
# OverallQual        0
# OverallCond        0
# YearBuilt          0
# YearRemodAdd       0
# MasVnrArea        15
# BsmtFinSF1         1
# BsmtFinSF2         1
# BsmtUnfSF          1
# TotalBsmtSF        1
# 1stFlrSF           0
# 2ndFlrSF           0
# LowQualFinSF       0
# GrLivArea          0
# BsmtFullBath       2
# BsmtHalfBath       2
# FullBath           0
# HalfBath           0
# BedroomAbvGr       0
# KitchenAbvGr       0
# TotRmsAbvGrd       0
# Fireplaces         0
# GarageYrBlt       78
# GarageCars         1
# GarageArea         1
# WoodDeckSF         0
# OpenPorchSF        0
# EnclosedPorch      0
# 3SsnPorch          0
# ScreenPorch        0
# PoolArea           0
# MiscVal            0
# MoSold             0
# YrSold             0
# dtype: int64

# %%
df2.head()
# Out:
#      Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0  1461          20         80.0    11622            5            6
# 1  1462          20         81.0    14267            6            6
# 2  1463          60         74.0    13830            5            5
# 3  1464          60         78.0     9978            6            6
# 4  1465         120         43.0     5005            8            5
#
#    YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# 0       1961          1961         0.0       468.0       144.0      270.0
# 1       1958          1958       108.0       923.0         0.0      406.0
# 2       1997          1998         0.0       791.0         0.0      137.0
# 3       1998          1998        20.0       602.0         0.0      324.0
# 4       1992          1992         0.0       263.0         0.0     1017.0
#
#    TotalBsmtSF  1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  \
# ...

# %%
df2.fillna(df2.mean(),inplace=True)

# %%
df2.head()
# Out:
#      Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0  1461          20         80.0    11622            5            6
# 1  1462          20         81.0    14267            6            6
# 2  1463          60         74.0    13830            5            5
# 3  1464          60         78.0     9978            6            6
# 4  1465         120         43.0     5005            8            5
#
#    YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# 0       1961          1961         0.0       468.0       144.0      270.0
# 1       1958          1958       108.0       923.0         0.0      406.0
# 2       1997          1998         0.0       791.0         0.0      137.0
# 3       1998          1998        20.0       602.0         0.0      324.0
# 4       1992          1992         0.0       263.0         0.0     1017.0
#
#    TotalBsmtSF  1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  \
# ...

# %%
df3 = df2.loc[:,df2.columns.isin(['OverallQual',
 'GrLivArea',
 'GarageCars',
 'GarageArea',
 'TotalBsmtSF',
 '1stFlrSF',
 'FullBath',
 'TotRmsAbvGrd',
 'YearBuilt',
 'YearRemodAdd',
 'GarageYrBlt',
 'MasVnrArea',
 'Fireplaces',
 'BsmtFinSF1',
 'LotFrontage',
 'WoodDeckSF',
 '2ndFlrSF',
 'OpenPorchSF',
 'HalfBath'])]

#df1 = df.loc[:, df.columns.isin(list1[0:20])]

# %%
len(df3.columns)
# Out:
# 19

# %%
df3.head()
# Out:
#    LotFrontage  OverallQual  YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  \
# 0         80.0            5       1961          1961         0.0       468.0
# 1         81.0            6       1958          1958       108.0       923.0
# 2         74.0            5       1997          1998         0.0       791.0
# 3         78.0            6       1998          1998        20.0       602.0
# 4         43.0            8       1992          1992         0.0       263.0
#
#    TotalBsmtSF  1stFlrSF  2ndFlrSF  GrLivArea  FullBath  HalfBath  \
# 0        882.0       896         0        896         1         0
# 1       1329.0      1329         0       1329         1         1
# 2        928.0       928       701       1629         2         1
# 3        926.0       926       678       1604         2         1
# 4       1280.0      1280         0       1280         2         0
#
#    TotRmsAbvGrd  Fireplaces  GarageYrBlt  GarageCars  GarageArea  WoodDeckSF  \
# ...

# %%
type(df3)
output = lr.predict(df3)
type(output)
# Out:
# numpy.ndarray

# %%
df_output = pd.DataFrame(output,columns=['Predicted'])
#df_output['Predicted'][:]== output[:]

# %%
df_output
# Out:
#           Predicted
# 0     117359.863428
# 1     161843.541497
# 2     182109.448555
# 3     203294.251118
# 4     199823.903210
# 5     185472.308039
# 6     193374.946181
# 7     176020.905789
# 8     206216.232542
# 9     116966.608254
# 10    215228.035238
# 11    131312.276127
# 12    111763.797972
# 13    170954.126418
# 14    135741.208370
# 15    298760.665610
# 16    240260.785569
# 17    281191.752617
# 18    259184.549155
# 19    364300.178383
# 20    282708.461646
# 21    224904.920742
# 22    175949.301927
# 23    186812.844513
# 24    197413.678291
# 25    209743.968056
# 26    270770.358735
# 27    251285.379469
# 28    192158.500884
# 29    210538.271448
# 30    201750.434689
# 31     97317.046060
# 32    204365.290362
# 33    267537.019218
# 34    274224.353662
# 35    227217.434282
# 36    188699.767451
# 37    177549.893613
# 38    177465.729865
# 39    163607.538672
# 40    182293.988033
# 41    171588.458594
# 42    261514.451381
# 43    245569.883007
# ...
